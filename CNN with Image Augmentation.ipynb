# %%
import tensorflow.keras
import glob
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img

# %matplotlib inline

# %%
IMG_DIM = (150, 150)

train_files = glob.glob('training_data/*')
train_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in train_files]
train_imgs = np.array(train_imgs)
train_labels = [fn.split('/')[1].split('.')[0].strip() for fn in train_files]

validation_files = glob.glob('validation_data/*')
validation_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in validation_files]
validation_imgs = np.array(validation_imgs)
validation_labels = [fn.split('/')[1].split('.')[0].strip() for fn in validation_files]

print('Train dataset shape:', train_imgs.shape, 
      '\tValidation dataset shape:', validation_imgs.shape)
# Out:
# Train dataset shape: (2916, 150, 150, 3) 	Validation dataset shape: (2844, 150, 150, 3)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(train_labels)
# encode wine type labels
train_labels_enc = le.transform(train_labels)
validation_labels_enc = le.transform(validation_labels)

print(train_labels[0:5], train_labels_enc[0:5])
# Out:
# ['cat', 'cat', 'dog', 'dog', 'dog'] [0 0 1 1 1]

# %%
train_datagen = ImageDataGenerator(rescale=1./255, zoom_range=0.3, rotation_range=50,
                                   width_shift_range=0.2, height_shift_range=0.2, shear_range=0.2, 
                                   horizontal_flip=True, fill_mode='nearest')

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
img_id = 2595
cat_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
cat = [next(cat_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(16, 6))
print('Labels:', [item[1][0] for item in cat])
l = [ax[i].imshow(cat[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['dog', 'dog', 'dog', 'dog', 'dog']

# %%
img_id = 1991
dog_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
dog = [next(dog_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(15, 6))
print('Labels:', [item[1][0] for item in dog])
l = [ax[i].imshow(dog[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['cat', 'cat', 'cat', 'cat', 'cat']

# %%
train_generator = train_datagen.flow(train_imgs, train_labels_enc, batch_size=30)
val_generator = val_datagen.flow(validation_imgs, validation_labels_enc, batch_size=20)

input_shape = (150, 150, 3)

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers

model = Sequential()

model.add(Conv2D(16, kernel_size=(3, 3), activation='relu', 
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))


model.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        9280
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 3,706,113
# Trainable params: 3,706,113
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(train_generator, steps_per_epoch=100, epochs=100,
                              validation_data=val_generator, validation_steps=50, verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 178s 2s/step - loss: 0.6941 - accuracy: 0.5027 - val_loss: 0.6891 - val_accuracy: 0.5200
# Epoch 2/100
# 100/100 [==============================] - 190s 2s/step - loss: 0.6920 - accuracy: 0.5286 - val_loss: 0.6854 - val_accuracy: 0.5590
# Epoch 3/100
# 100/100 [==============================] - 184s 2s/step - loss: 0.6853 - accuracy: 0.5447 - val_loss: 0.6787 - val_accuracy: 0.5470
# Epoch 4/100
# 100/100 [==============================] - 176s 2s/step - loss: 0.6745 - accuracy: 0.5753 - val_loss: 0.6565 - val_accuracy: 0.5970
# Epoch 5/100
# 100/100 [==============================] - 193s 2s/step - loss: 0.6627 - accuracy: 0.6112 - val_loss: 0.6447 - val_accuracy: 0.6220
# Epoch 6/100
# 100/100 [==============================] - 201s 2s/step - loss: 0.6595 - accuracy: 0.6018 - val_loss: 0.6252 - val_accuracy: 0.6370
# Epoch 7/100
# 100/100 [==============================] - 204s 2s/step - loss: 0.6516 - accuracy: 0.6186 - val_loss: 0.6212 - val_accuracy: 0.6540
# Epoch 8/100
# 100/100 [==============================] - 305s 3s/step - loss: 0.6392 - accuracy: 0.6317 - val_loss: 0.6139 - val_accuracy: 0.6540
# Epoch 9/100
# 100/100 [==============================] - 307s 3s/step - loss: 0.6312 - accuracy: 0.6551 - val_loss: 0.6059 - val_accuracy: 0.6670
# Epoch 10/100
# 100/100 [==============================] - 313s 3s/step - loss: 0.6244 - accuracy: 0.6543 - val_loss: 0.5922 - val_accuracy: 0.6810
# Epoch 11/100
# 100/100 [==============================] - 306s 3s/step - loss: 0.6164 - accuracy: 0.6640 - val_loss: 0.6238 - val_accuracy: 0.6550
# Epoch 12/100
# 100/100 [==============================] - 304s 3s/step - loss: 0.6053 - accuracy: 0.6734 - val_loss: 0.5788 - val_accuracy: 0.7030
# Epoch 13/100
# 100/100 [==============================] - 299s 3s/step - loss: 0.6077 - accuracy: 0.6619 - val_loss: 0.7023 - val_accuracy: 0.6010
# Epoch 14/100
# 100/100 [==============================] - 335s 3s/step - loss: 0.5929 - accuracy: 0.6794 - val_loss: 0.5586 - val_accuracy: 0.7010
# Epoch 15/100
# 100/100 [==============================] - 352s 4s/step - loss: 0.5999 - accuracy: 0.6687 - val_loss: 0.5531 - val_accuracy: 0.7150
# Epoch 16/100
# 100/100 [==============================] - 197s 2s/step - loss: 0.5843 - accuracy: 0.7002 - val_loss: 0.5498 - val_accuracy: 0.7310
# Epoch 17/100
# 100/100 [==============================] - 169s 2s/step - loss: 0.5764 - accuracy: 0.6897 - val_loss: 0.5665 - val_accuracy: 0.7020
# Epoch 18/100
# 100/100 [==============================] - 173s 2s/step - loss: 0.5694 - accuracy: 0.6978 - val_loss: 0.5724 - val_accuracy: 0.6960
# Epoch 19/100
# 100/100 [==============================] - 208s 2s/step - loss: 0.5701 - accuracy: 0.7056 - val_loss: 0.5273 - val_accuracy: 0.7390
# Epoch 20/100
# 100/100 [==============================] - 208s 2s/step - loss: 0.5648 - accuracy: 0.7040 - val_loss: 0.5342 - val_accuracy: 0.7370
# Epoch 21/100
# 100/100 [==============================] - 204s 2s/step - loss: 0.5614 - accuracy: 0.7033 - val_loss: 0.5087 - val_accuracy: 0.7420
# Epoch 22/100
# 100/100 [==============================] - 205s 2s/step - loss: 0.5505 - accuracy: 0.7214 - val_loss: 0.5381 - val_accuracy: 0.7480
# Epoch 23/100
# 100/100 [==============================] - 201s 2s/step - loss: 0.5615 - accuracy: 0.7073 - val_loss: 0.4986 - val_accuracy: 0.7650
# Epoch 24/100
# 100/100 [==============================] - 203s 2s/step - loss: 0.5452 - accuracy: 0.7164 - val_loss: 0.5147 - val_accuracy: 0.7500
# Epoch 25/100
# 100/100 [==============================] - 201s 2s/step - loss: 0.5407 - accuracy: 0.7177 - val_loss: 0.4944 - val_accuracy: 0.7700
# Epoch 26/100
# 100/100 [==============================] - 192s 2s/step - loss: 0.5455 - accuracy: 0.7217 - val_loss: 0.5069 - val_accuracy: 0.7470
# Epoch 27/100
# 100/100 [==============================] - 190s 2s/step - loss: 0.5319 - accuracy: 0.7256 - val_loss: 0.4924 - val_accuracy: 0.7700
# Epoch 28/100
# 100/100 [==============================] - 190s 2s/step - loss: 0.5222 - accuracy: 0.7332 - val_loss: 0.4812 - val_accuracy: 0.7790
# Epoch 29/100
# 100/100 [==============================] - 191s 2s/step - loss: 0.5277 - accuracy: 0.7362 - val_loss: 0.5308 - val_accuracy: 0.7560
# Epoch 30/100
# 100/100 [==============================] - 192s 2s/step - loss: 0.5229 - accuracy: 0.7403 - val_loss: 0.5210 - val_accuracy: 0.7700
# Epoch 31/100
# 100/100 [==============================] - 185s 2s/step - loss: 0.5297 - accuracy: 0.7381 - val_loss: 0.4774 - val_accuracy: 0.7820
# Epoch 32/100
# 100/100 [==============================] - 178s 2s/step - loss: 0.5293 - accuracy: 0.7373 - val_loss: 0.5560 - val_accuracy: 0.7470
# Epoch 33/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.5023 - accuracy: 0.7470 - val_loss: 0.4682 - val_accuracy: 0.7770
# Epoch 34/100
# 100/100 [==============================] - 176s 2s/step - loss: 0.5137 - accuracy: 0.7473 - val_loss: 0.5037 - val_accuracy: 0.7590
# Epoch 35/100
# 100/100 [==============================] - 177s 2s/step - loss: 0.5175 - accuracy: 0.7473 - val_loss: 0.5106 - val_accuracy: 0.7690
# Epoch 36/100
# 100/100 [==============================] - 176s 2s/step - loss: 0.5092 - accuracy: 0.7507 - val_loss: 0.4832 - val_accuracy: 0.7790
# Epoch 37/100
# 100/100 [==============================] - 176s 2s/step - loss: 0.5011 - accuracy: 0.7534 - val_loss: 0.4602 - val_accuracy: 0.8000
# Epoch 38/100
# 100/100 [==============================] - 176s 2s/step - loss: 0.5131 - accuracy: 0.7456 - val_loss: 0.4612 - val_accuracy: 0.7870
# Epoch 39/100
# 100/100 [==============================] - 176s 2s/step - loss: 0.5012 - accuracy: 0.7557 - val_loss: 0.5668 - val_accuracy: 0.7480
# Epoch 40/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.4908 - accuracy: 0.7669 - val_loss: 0.5329 - val_accuracy: 0.7600
# Epoch 41/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4860 - accuracy: 0.7641 - val_loss: 0.4499 - val_accuracy: 0.7960
# Epoch 42/100
# 100/100 [==============================] - 177s 2s/step - loss: 0.4862 - accuracy: 0.7627 - val_loss: 0.4991 - val_accuracy: 0.7640
# Epoch 43/100
# 100/100 [==============================] - 173s 2s/step - loss: 0.4902 - accuracy: 0.7615 - val_loss: 0.4430 - val_accuracy: 0.8040
# Epoch 44/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4808 - accuracy: 0.7671 - val_loss: 0.4390 - val_accuracy: 0.7920
# Epoch 45/100
# 100/100 [==============================] - 176s 2s/step - loss: 0.4871 - accuracy: 0.7667 - val_loss: 0.4482 - val_accuracy: 0.8080
# Epoch 46/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.4782 - accuracy: 0.7696 - val_loss: 0.4804 - val_accuracy: 0.7880
# Epoch 47/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4556 - accuracy: 0.7812 - val_loss: 0.4384 - val_accuracy: 0.8040
# Epoch 48/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4657 - accuracy: 0.7712 - val_loss: 0.4525 - val_accuracy: 0.8130
# Epoch 49/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4846 - accuracy: 0.7695 - val_loss: 0.4498 - val_accuracy: 0.7970
# Epoch 50/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.4703 - accuracy: 0.7799 - val_loss: 0.5070 - val_accuracy: 0.7750
# Epoch 51/100
# 100/100 [==============================] - 176s 2s/step - loss: 0.4616 - accuracy: 0.7853 - val_loss: 0.4393 - val_accuracy: 0.7900
# Epoch 52/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4619 - accuracy: 0.7735 - val_loss: 0.4487 - val_accuracy: 0.8000
# Epoch 53/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4620 - accuracy: 0.7752 - val_loss: 0.4602 - val_accuracy: 0.7860
# Epoch 54/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4573 - accuracy: 0.7930 - val_loss: 0.4664 - val_accuracy: 0.8000
# Epoch 55/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.4528 - accuracy: 0.7890 - val_loss: 0.4174 - val_accuracy: 0.8080
# Epoch 56/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4629 - accuracy: 0.7745 - val_loss: 0.4113 - val_accuracy: 0.8170
# Epoch 57/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.4597 - accuracy: 0.7883 - val_loss: 0.4186 - val_accuracy: 0.8110
# Epoch 58/100
# 100/100 [==============================] - 176s 2s/step - loss: 0.4501 - accuracy: 0.7937 - val_loss: 0.4435 - val_accuracy: 0.8150
# Epoch 59/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.4592 - accuracy: 0.7870 - val_loss: 0.4357 - val_accuracy: 0.8070
# Epoch 60/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4447 - accuracy: 0.7873 - val_loss: 0.4296 - val_accuracy: 0.8190
# Epoch 61/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4408 - accuracy: 0.7893 - val_loss: 0.4556 - val_accuracy: 0.7950
# Epoch 62/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4344 - accuracy: 0.7923 - val_loss: 0.4207 - val_accuracy: 0.8130
# Epoch 63/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.4413 - accuracy: 0.7950 - val_loss: 0.4223 - val_accuracy: 0.8230
# Epoch 64/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.4277 - accuracy: 0.8068 - val_loss: 0.4221 - val_accuracy: 0.8180
# Epoch 65/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4296 - accuracy: 0.7920 - val_loss: 0.4011 - val_accuracy: 0.8340
# Epoch 66/100
# 100/100 [==============================] - 173s 2s/step - loss: 0.4410 - accuracy: 0.7951 - val_loss: 0.4005 - val_accuracy: 0.8220
# Epoch 67/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.4365 - accuracy: 0.7981 - val_loss: 0.4164 - val_accuracy: 0.8200
# Epoch 68/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4405 - accuracy: 0.8033 - val_loss: 0.4387 - val_accuracy: 0.7980
# Epoch 69/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4181 - accuracy: 0.8031 - val_loss: 0.4568 - val_accuracy: 0.8050
# Epoch 70/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.4394 - accuracy: 0.7940 - val_loss: 0.3869 - val_accuracy: 0.8290
# Epoch 71/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4106 - accuracy: 0.8085 - val_loss: 0.3827 - val_accuracy: 0.8400
# Epoch 72/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.4221 - accuracy: 0.8014 - val_loss: 0.4031 - val_accuracy: 0.8230
# Epoch 73/100
# 100/100 [==============================] - 173s 2s/step - loss: 0.4068 - accuracy: 0.8100 - val_loss: 0.4018 - val_accuracy: 0.8340
# Epoch 74/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4235 - accuracy: 0.8110 - val_loss: 0.4433 - val_accuracy: 0.8140
# Epoch 75/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.4264 - accuracy: 0.8076 - val_loss: 0.4608 - val_accuracy: 0.8200
# Epoch 76/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4190 - accuracy: 0.8113 - val_loss: 0.4120 - val_accuracy: 0.8240
# Epoch 77/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.4142 - accuracy: 0.8115 - val_loss: 0.4017 - val_accuracy: 0.8410
# Epoch 78/100
# 100/100 [==============================] - 173s 2s/step - loss: 0.4170 - accuracy: 0.8096 - val_loss: 0.4144 - val_accuracy: 0.8210
# Epoch 79/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4079 - accuracy: 0.8093 - val_loss: 0.4036 - val_accuracy: 0.8320
# Epoch 80/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.4114 - accuracy: 0.8106 - val_loss: 0.3990 - val_accuracy: 0.8350
# Epoch 81/100
# 100/100 [==============================] - 178s 2s/step - loss: 0.4232 - accuracy: 0.8182 - val_loss: 0.3922 - val_accuracy: 0.8190
# Epoch 82/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4085 - accuracy: 0.8199 - val_loss: 0.4409 - val_accuracy: 0.7980
# Epoch 83/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4039 - accuracy: 0.8200 - val_loss: 0.4385 - val_accuracy: 0.8300
# Epoch 84/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4014 - accuracy: 0.8172 - val_loss: 0.4316 - val_accuracy: 0.8170
# Epoch 85/100
# 100/100 [==============================] - 173s 2s/step - loss: 0.4080 - accuracy: 0.8184 - val_loss: 0.4375 - val_accuracy: 0.8160
# Epoch 86/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.4101 - accuracy: 0.8202 - val_loss: 0.4482 - val_accuracy: 0.8210
# Epoch 87/100
# 100/100 [==============================] - 173s 2s/step - loss: 0.3904 - accuracy: 0.8269 - val_loss: 0.4032 - val_accuracy: 0.8290
# Epoch 88/100
# 100/100 [==============================] - 176s 2s/step - loss: 0.3932 - accuracy: 0.8313 - val_loss: 0.4332 - val_accuracy: 0.8220
# Epoch 89/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.3974 - accuracy: 0.8259 - val_loss: 0.5354 - val_accuracy: 0.7990
# Epoch 90/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.3984 - accuracy: 0.8216 - val_loss: 0.3958 - val_accuracy: 0.8290
# Epoch 91/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.3956 - accuracy: 0.8196 - val_loss: 0.4041 - val_accuracy: 0.8290
# Epoch 92/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.4016 - accuracy: 0.8175 - val_loss: 0.4127 - val_accuracy: 0.8420
# Epoch 93/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.3854 - accuracy: 0.8347 - val_loss: 0.3931 - val_accuracy: 0.8410
# Epoch 94/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.3835 - accuracy: 0.8293 - val_loss: 0.3802 - val_accuracy: 0.8350
# Epoch 95/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.3888 - accuracy: 0.8273 - val_loss: 0.4004 - val_accuracy: 0.8170
# Epoch 96/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.3781 - accuracy: 0.8360 - val_loss: 0.5027 - val_accuracy: 0.8100
# Epoch 97/100
# 100/100 [==============================] - 174s 2s/step - loss: 0.3903 - accuracy: 0.8313 - val_loss: 0.3838 - val_accuracy: 0.8440
# Epoch 98/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.3764 - accuracy: 0.8253 - val_loss: 0.3730 - val_accuracy: 0.8470
# Epoch 99/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.3810 - accuracy: 0.8327 - val_loss: 0.3632 - val_accuracy: 0.8430
# Epoch 100/100
# 100/100 [==============================] - 175s 2s/step - loss: 0.3872 - accuracy: 0.8317 - val_loss: 0.4280 - val_accuracy: 0.8240

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('CNN with Image Augmentation Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,101))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 101, 10))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 101, 10))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
model.save('cats_dogs_cnn_img_aug.h5')
